# %% [markdown]
# # Machine Learning Model Training: Predict if Song will be Liked by Me

# %%
import pandas as pd
df_ready_to_used = pd.read_csv('./data/dataset_eda_and_preprocessed.csv').drop(columns='Unnamed: 0')
df_ready_to_used
# Out:
#                          artists        track_genre  popularity  duration_ms  \
# 0        The Killers;Ryan Pardey               rock           0       245106
# 1                    John Denver  singer-songwriter          62       245533
# 2                       Skindred              metal           0       183760
# 3                      Lyn Lapid         songwriter          58       190243
# 4                      Alphaxone            iranian          11       434000
# ...                          ...                ...         ...          ...
# 11339                     Eagles               rock          76       393640
# 11340  Clean Bandit;Zara Larsson              dance          76       212733
# 11341   Martin Garrix;Bebe Rexha              house          80       195854
# 11342               Fall Out Boy               rock          82       228458
# 11343              Martin Jensen              dance          69       174751
#
#        explicit  danceability    energy  key   loudness  mode  speechiness  \
# 0         False      0.588000  0.847000    8  -4.164000     1     0.070500
# 1         False      0.406000  0.188000    7 -13.039000     1     0.032400
# 2         False      0.583000  0.915000    0  -4.007000     1     0.081100
# 3         False      0.492000  0.227000    2 -10.679000     1     0.027700
# 4         False      0.144000  0.167000    1 -24.642000     0     0.041900
# ...         ...           ...       ...  ...        ...   ...          ...
# 11339     False      0.533000  0.360000    1 -12.633000     1     0.028200
# 11340     False      0.715000  0.605000    0  -5.128000     0     0.042800
# 11341     False      0.660916  0.433850    4  -8.280813     0     0.032385
# 11342     False      0.607713  0.475443    8  -6.713909     1     0.040751
# 11343     False      0.716196  0.819401    8  -3.267787     0     0.091744
#
#        acousticness  instrumentalness  liveness   valence       tempo  target
# 0          0.060100      0.000000e+00  0.307000  0.662000  120.041000       0
# 1          0.852000      0.000000e+00  0.105000  0.629000  120.757000       0
# 2          0.002140      0.000000e+00  0.395000  0.880000  172.097000       0
# 3          0.772000      6.570000e-05  0.106000  0.229000  137.697000       0
# 4          0.877000      9.670000e-01  0.114000  0.039300  103.660000       0
# ...             ...               ...       ...       ...         ...     ...
# 11339      0.080500      1.030000e-05  0.063100  0.299000  131.229000       1
# 11340      0.239000      1.410000e-05  0.189000  0.454000  122.956000       1
# 11341      0.091762      2.478347e-05  0.212396  0.431065  103.553402       1
# 11342      0.199800      6.372013e-07  0.350642  0.522158  170.416324       1
# 11343      0.129659      0.000000e+00  0.182341  0.389540  110.858745       1
#
# [11344 rows x 17 columns]

# %% [markdown]
# ## Split Train and Test
#
# We will use the ratio of training/validation/test = **60/20/20**

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction import DictVectorizer

df_full_train, df_test = train_test_split(df_ready_to_used, test_size=0.2, random_state=42)
df_train, df_val = train_test_split(df_full_train, test_size=0.2, random_state=42)

df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

y_train = df_train.target.values
y_val = df_val.target.values
y_test = df_test.target.values

del df_train['target']
del df_val['target']
del df_test['target']

dv = DictVectorizer(sparse=False)

train_dict = df_train.to_dict(orient='records')
X_train = dv.fit_transform(train_dict)

val_dict = df_val.to_dict(orient='records')
X_val = dv.transform(val_dict)

test_dict = df_test.to_dict(orient='records')
X_test = dv.transform(test_dict)

# %% [markdown]
# ## Training Untuned Version of SGD Classifier

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import roc_auc_score

model = SGDClassifier(loss='log_loss', random_state=42)
model.fit(X_train, y_train)
# Out:
# SGDClassifier(loss='log_loss', random_state=42)

# %%
model.get_params()
# Out:
# {'alpha': 0.0001,
#  'average': False,
#  'class_weight': None,
#  'early_stopping': False,
#  'epsilon': 0.1,
#  'eta0': 0.0,
#  'fit_intercept': True,
#  'l1_ratio': 0.15,
#  'learning_rate': 'optimal',
#  'loss': 'log_loss',
#  'max_iter': 1000,
#  'n_iter_no_change': 5,
#  'n_jobs': None,
#  'penalty': 'l2',
#  'power_t': 0.5,
#  'random_state': 42,
#  'shuffle': True,
#  'tol': 0.001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %%
y_pred = model.predict_proba(X_train)[:, 1]
print(f"Score on training set: {roc_auc_score(y_train, y_pred)}")
# Out:
# Score on training set: 0.5

# %%
y_pred = model.predict_proba(X_val)[:, 1]
print(f"Score on validation set: {roc_auc_score(y_val, y_pred)}")
# Out:
# Score on validation set: 0.5

# %%
y_pred = model.predict_proba(X_test)[:, 1]
print(f"Score on test set: {roc_auc_score(y_test, y_pred)}")
# Out:
# Score on test set: 0.5

# %% [markdown]
# ## Train a Tuned Version of SGDClassifier

# %%
from sklearn.model_selection import RandomizedSearchCV

param_grid = {
    'alpha': [0.0001, 0.001, 0.01, 0.1],
    'tol': [0.0001, 0.001, 0.01, 0.1],
    'penalty' : ['l2', 'l1', 'elasticnet', None],
    'eta0': [0.0001, 0.001, 0.01],
    'learning_rate' : ['constant', 'optimal', 'invscaling', 'adaptive'],
    'max_iter': [100, 500],
}
grid_search = RandomizedSearchCV(
    SGDClassifier(loss='log_loss', random_state=42),
    param_distributions=param_grid,
    n_iter=10,
    cv=5, verbose=3, n_jobs=-1, scoring='roc_auc', random_state=42
)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 3/5] END alpha=0.1, eta0=0.01, learning_rate=optimal, max_iter=500, penalty=l2, tol=0.1;, score=0.533 total time=   8.0s
# [CV 2/5] END alpha=0.1, eta0=0.01, learning_rate=optimal, max_iter=500, penalty=l2, tol=0.1;, score=0.534 total time=  11.8s
# [CV 3/5] END alpha=0.01, eta0=0.01, learning_rate=adaptive, max_iter=100, penalty=l1, tol=0.01;, score=0.864 total time=  13.3s
# [CV 2/5] END alpha=0.01, eta0=0.01, learning_rate=adaptive, max_iter=100, penalty=l1, tol=0.01;, score=0.897 total time=  14.0s
# [CV 1/5] END alpha=0.01, eta0=0.01, learning_rate=adaptive, max_iter=100, penalty=l1, tol=0.01;, score=0.898 total time=  15.8s
# [CV 5/5] END alpha=0.01, eta0=0.01, learning_rate=adaptive, max_iter=100, penalty=l1, tol=0.01;, score=0.850 total time=  16.5s
# [CV 4/5] END alpha=0.01, eta0=0.01, learning_rate=adaptive, max_iter=100, penalty=l1, tol=0.01;, score=0.861 total time=  16.3s
# [CV 1/5] END alpha=0.1, eta0=0.01, learning_rate=optimal, max_iter=500, penalty=l2, tol=0.1;, score=0.522 total time=  20.6s
# [CV 4/5] END alpha=0.01, eta0=0.0001, learning_rate=invscaling, max_iter=500, penalty=None, tol=0.0001;, score=0.604 total time=   4.8s
# [CV 2/5] END alpha=0.1, eta0=0.001, learning_rate=constant, max_iter=100, penalty=None, tol=0.01;, score=0.518 total time=   0.9s
# [CV 4/5] END alpha=0.1, eta0=0.01, learning_rate=optimal, max_iter=500, penalty=l2, tol=0.1;, score=0.587 total time=  13.2s
# [CV 1/5] END alpha=0.01, eta0=0.0001, learning_rate=invscaling, max_iter=500, penalty=None, tol=0.0001;, score=0.546 total time=  10.0s
# [CV 1/5] END alpha=0.1, eta0=0.001, learning_rate=constant, max_iter=100, penalty=None, tol=0.01;, score=0.511 total time=   2.3s
# [CV 3/5] END alpha=0.1, eta0=0.001, learning_rate=constant, max_iter=100, penalty=None, tol=0.01;, score=0.527 total time=   1.4s
# [CV 5/5] END alpha=0.1, eta0=0.01, learning_rate=optimal, max_iter=500, penalty=l2, tol=0.1;, score=0.570 total time=  11.4s
# [CV 5/5] END alpha=0.01, eta0=0.0001, learning_rate=invscaling, max_iter=500, penalty=None, tol=0.0001;, score=0.454 total time=   7.3s
# [CV 3/5] END alpha=0.01, eta0=0.0001, learning_rate=invscaling, max_iter=500, penalty=None, tol=0.0001;, score=0.539 total time=   8.3s
# [CV 5/5] END alpha=0.1, eta0=0.001, learning_rate=constant, max_iter=100, penalty=None, tol=0.01;, score=0.438 total time=   2.3s
# [CV 4/5] END alpha=0.1, eta0=0.001, learning_rate=constant, max_iter=100, penalty=None, tol=0.01;, score=0.430 total time=   3.3s
# [CV 2/5] END alpha=0.01, eta0=0.0001, learning_rate=invscaling, max_iter=500, penalty=None, tol=0.0001;, score=0.544 total time=  12.5s
# [CV 3/5] END alpha=0.01, eta0=0.01, learning_rate=adaptive, max_iter=100, penalty=elasticnet, tol=0.01;, score=0.846 total time=  14.7s
# [CV 1/5] END alpha=0.01, eta0=0.01, learning_rate=adaptive, max_iter=100, penalty=elasticnet, tol=0.01;, score=0.847 total time=  16.6s
# [CV 2/5] END alpha=0.01, eta0=0.01, learning_rate=adaptive, max_iter=100, penalty=elasticnet, tol=0.01;, score=0.872 total time=  16.1s
# [CV 5/5] END alpha=0.01, eta0=0.01, learning_rate=adaptive, max_iter=100, penalty=elasticnet, tol=0.01;, score=0.837 total time=  18.3s
# [CV 2/5] END alpha=0.01, eta0=0.01, learning_rate=constant, max_iter=500, penalty=l1, tol=0.0001;, score=0.518 total time=   1.0s
# [CV 4/5] END alpha=0.01, eta0=0.01, learning_rate=adaptive, max_iter=100, penalty=elasticnet, tol=0.01;, score=0.890 total time=  20.3s
# [CV 1/5] END alpha=0.01, eta0=0.01, learning_rate=constant, max_iter=500, penalty=l1, tol=0.0001;, score=0.512 total time=   4.8s
# [CV 2/5] END alpha=0.01, eta0=0.01, learning_rate=invscaling, max_iter=100, penalty=l1, tol=0.1;, score=0.952 total time=  19.4s
# [CV 3/5] END alpha=0.01, eta0=0.01, learning_rate=invscaling, max_iter=100, penalty=l1, tol=0.1;, score=0.501 total time=  21.4s
# [CV 3/5] END alpha=0.01, eta0=0.01, learning_rate=constant, max_iter=500, penalty=l1, tol=0.0001;, score=0.527 total time=   4.7s
# [CV 5/5] END alpha=0.01, eta0=0.01, learning_rate=constant, max_iter=500, penalty=l1, tol=0.0001;, score=0.436 total time=   4.4s
# [CV 1/5] END alpha=0.01, eta0=0.01, learning_rate=invscaling, max_iter=100, penalty=l1, tol=0.1;, score=0.518 total time=  24.8s
# [CV 4/5] END alpha=0.01, eta0=0.01, learning_rate=invscaling, max_iter=100, penalty=l1, tol=0.1;, score=0.584 total time=  13.3s
# [CV 4/5] END alpha=0.01, eta0=0.01, learning_rate=constant, max_iter=500, penalty=l1, tol=0.0001;, score=0.438 total time=   8.3s
# [CV 1/5] END alpha=0.0001, eta0=0.0001, learning_rate=adaptive, max_iter=500, penalty=elasticnet, tol=0.001;, score=0.788 total time=  14.6s
# [CV 2/5] END alpha=0.0001, eta0=0.0001, learning_rate=adaptive, max_iter=500, penalty=elasticnet, tol=0.001;, score=0.605 total time=  13.2s
# [CV 5/5] END alpha=0.0001, eta0=0.0001, learning_rate=adaptive, max_iter=500, penalty=elasticnet, tol=0.001;, score=0.762 total time=  13.9s
# [CV 3/5] END alpha=0.0001, eta0=0.0001, learning_rate=adaptive, max_iter=500, penalty=elasticnet, tol=0.001;, score=0.812 total time=  16.7s
# [CV 4/5] END alpha=0.0001, eta0=0.0001, learning_rate=adaptive, max_iter=500, penalty=elasticnet, tol=0.001;, score=0.627 total time=  16.1s
# [CV 1/5] END alpha=0.001, eta0=0.0001, learning_rate=invscaling, max_iter=500, penalty=l2, tol=0.01;, score=0.517 total time=  15.0s
# [CV 5/5] END alpha=0.01, eta0=0.01, learning_rate=invscaling, max_iter=100, penalty=l1, tol=0.1;, score=0.933 total time=  27.5s
# [CV 3/5] END alpha=0.001, eta0=0.0001, learning_rate=invscaling, max_iter=500, penalty=l2, tol=0.01;, score=0.500 total time=   8.1s
# [CV 4/5] END alpha=0.001, eta0=0.0001, learning_rate=invscaling, max_iter=500, penalty=l2, tol=0.01;, score=0.588 total time=   8.3s
# [CV 2/5] END alpha=0.001, eta0=0.0001, learning_rate=invscaling, max_iter=500, penalty=l2, tol=0.01;, score=0.544 total time=  16.9s
# [CV 5/5] END alpha=0.001, eta0=0.0001, learning_rate=invscaling, max_iter=500, penalty=l2, tol=0.01;, score=0.573 total time=   5.4s
# [CV 4/5] END alpha=0.1, eta0=0.0001, learning_rate=invscaling, max_iter=500, penalty=l1, tol=0.01;, score=0.430 total time=   6.8s
# [CV 3/5] END alpha=0.1, eta0=0.0001, learning_rate=invscaling, max_iter=500, penalty=l1, tol=0.01;, score=0.484 total time=   9.7s
# [CV 2/5] END alpha=0.1, eta0=0.0001, learning_rate=invscaling, max_iter=500, penalty=l1, tol=0.01;, score=0.952 total time=  11.5s
# [CV 5/5] END alpha=0.1, eta0=0.0001, learning_rate=invscaling, max_iter=500, penalty=l1, tol=0.01;, score=0.451 total time=   9.5s
# [CV 1/5] END alpha=0.1, eta0=0.0001, learning_rate=invscaling, max_iter=500, penalty=l1, tol=0.01;, score=0.959 total time=  14.2s
# RandomizedSearchCV(cv=5,
#                    estimator=SGDClassifier(loss='log_loss', random_state=42),
#                    n_jobs=-1,
#                    param_distributions={'alpha': [0.0001, 0.001, 0.01, 0.1],
#                                         'eta0': [0.0001, 0.001, 0.01],
#                                         'learning_rate': ['constant', 'optimal',
#                                                           'invscaling',
#                                                           'adaptive'],
#                                         'max_iter': [100, 500],
#                                         'penalty': ['l2', 'l1', 'elasticnet',
#                                                     None],
#                                         'tol': [0.0001, 0.001, 0.01, 0.1]},
#                    random_state=42, scoring='roc_auc', verbose=3)

# %%
final_model = grid_search.best_estimator_
final_model
# Out:
# SGDClassifier(alpha=0.01, eta0=0.01, learning_rate='adaptive', loss='log_loss',
#               max_iter=100, penalty='l1', random_state=42, tol=0.01)

# %% [markdown]
# We get the best model of `SGDClassfier` with parameter alpha=0.01, eta0=0.01, learning_rate=adaptive, max_iter=100 and penalty=l1

# %%
y_pred = final_model.predict_proba(X_train)[:, 1]
print(f"Score on training set: {roc_auc_score(y_train, y_pred)}")
# Out:
# Score on training set: 0.8091939881637943

# %%
y_pred = final_model.predict_proba(X_val)[:, 1]
print(f"Score on validation set: {roc_auc_score(y_val, y_pred)}")
# Out:
# Score on validation set: 0.8289620691581475

# %%
y_pred = final_model.predict_proba(X_test)[:, 1]
print(f"Score on test set: {roc_auc_score(y_test, y_pred)}")
# Out:
# Score on test set: 0.7998814604077762

# %% [markdown]
# ## Trying the second model: LightGBM

# %%
# !pip install lightgbm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting lightgbm
#   Downloading lightgbm-4.2.0-py3-none-manylinux_2_28_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: numpy in /opt/conda/envs/ml-zoomcamp/lib/python3.9/site-packages (from lightgbm) (1.26.0)
# Requirement already satisfied: scipy in /opt/conda/envs/ml-zoomcamp/lib/python3.9/site-packages (from lightgbm) (1.11.3)
# Downloading lightgbm-4.2.0-py3-none-manylinux_2_28_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 2.0 MB/s eta 0:00:0000:0100:01
# Installing collected packages: lightgbm
# Successfully installed lightgbm-4.2.0

# %%
from lightgbm import LGBMClassifier

lgb_params = {
    'min_child_weight': [1, 5, 10],
    'num_leaves': [10, 20, 30, 40],
    'boosting_type': ['gbdt', 'dart'],
    'learning_rate': [0.5, 0.1, 0.05, 0.01, 0.005],
    'n_estimators': [10, 50, 100, 500]
}


lgb = LGBMClassifier(objective='binary', nthread=8, seed=1, verbosity=1)
random_search = RandomizedSearchCV(
    lgb,
    param_distributions=lgb_params,
    n_iter=30,
    scoring='roc_auc',
    n_jobs=4, cv=5, verbose=3, random_state=42
)

random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001309 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2990
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 179
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010077 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2980
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 174
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011135 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2990
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 179
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.015220 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2979
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 174
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 1/5] END boosting_type=gbdt, learning_rate=0.1, min_child_weight=5, n_estimators=100, num_leaves=20;, score=0.994 total time=   0.6s
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 2/5] END boosting_type=gbdt, learning_rate=0.1, min_child_weight=5, n_estimators=100, num_leaves=20;, score=0.995 total time=   0.9s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.035786 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2987
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 178
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004340 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2990
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 179
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 5/5] END boosting_type=gbdt, learning_rate=0.1, min_child_weight=5, n_estimators=100, num_leaves=20;, score=0.993 total time=   1.1s
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 4/5] END boosting_type=gbdt, learning_rate=0.1, min_child_weight=5, n_estimators=100, num_leaves=20;, score=0.994 total time=   1.8s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010556 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2980
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 174
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [CV 3/5] END boosting_type=gbdt, learning_rate=0.1, min_child_weight=5, n_estimators=100, num_leaves=20;, score=0.997 total time=   2.1s
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001805 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2990
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 179
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009190 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2979
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 174
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [CV 3/5] END boosting_type=dart, learning_rate=0.01, min_child_weight=5, n_estimators=500, num_leaves=30;, score=0.985 total time=   6.4s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.022957 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2987
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 178
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [CV 1/5] END boosting_type=dart, learning_rate=0.01, min_child_weight=5, n_estimators=500, num_leaves=30;, score=0.980 total time=  10.8s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.016419 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2990
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 179
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [CV 1/5] END boosting_type=dart, learning_rate=0.01, min_child_weight=1, n_estimators=100, num_leaves=30;, score=0.975 total time=   2.9s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011090 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2980
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 174
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [CV 5/5] END boosting_type=dart, learning_rate=0.01, min_child_weight=5, n_estimators=500, num_leaves=30;, score=0.979 total time=   7.1s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003406 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2990
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 179
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [CV 2/5] END boosting_type=dart, learning_rate=0.01, min_child_weight=5, n_estimators=500, num_leaves=30;, score=0.984 total time=  14.2s
# [CV 3/5] END boosting_type=dart, learning_rate=0.01, min_child_weight=1, n_estimators=100, num_leaves=30;, score=0.978 total time=   0.7s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.013623 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2979
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 174
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009060 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2987
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 178
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [CV 2/5] END boosting_type=dart, learning_rate=0.01, min_child_weight=1, n_estimators=100, num_leaves=30;, score=0.977 total time=   2.6s
# [CV 4/5] END boosting_type=dart, learning_rate=0.01, min_child_weight=1, n_estimators=100, num_leaves=30;, score=0.979 total time=   1.7s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001376 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2990
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 179
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [CV 4/5] END boosting_type=dart, learning_rate=0.01, min_child_weight=5, n_estimators=500, num_leaves=30;, score=0.983 total time=  15.6s
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001363 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2990
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 179
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 1/5] END boosting_type=dart, learning_rate=0.5, min_child_weight=10, n_estimators=50, num_leaves=20;, score=0.990 total time=   0.6s
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012988 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2980
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 174
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 5/5] END boosting_type=dart, learning_rate=0.01, min_child_weight=1, n_estimators=100, num_leaves=30;, score=0.970 total time=   2.1s[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 3/5] END boosting_type=dart, learning_rate=0.5, min_child_weight=10, n_estimators=50, num_leaves=20;, score=0.994 total time=   0.5s
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011953 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2979
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 174
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005016 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2990
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 179
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.028579 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2987
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 178
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 2/5] END boosting_type=dart, learning_rate=0.5, min_child_weight=10, n_estimators=50, num_leaves=20;, score=0.993 total time=   1.3s
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.013224 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Total Bins 2980
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 174
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 4/5] END boosting_type=dart, learning_rate=0.5, min_child_weight=10, n_estimators=50, num_leaves=20;, score=0.992 total time=   1.3s
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 5/5] END boosting_type=dart, learning_rate=0.5, min_child_weight=10, n_estimators=50, num_leaves=20;, score=0.989 total time=   1.3s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010337 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2990
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 179
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004131 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2979
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 174
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [CV 1/5] END boosting_type=dart, learning_rate=0.01, min_child_weight=1, n_estimators=500, num_leaves=40;, score=0.985 total time=  10.8s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.030538 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2987
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 178
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [CV 2/5] END boosting_type=dart, learning_rate=0.01, min_child_weight=1, n_estimators=500, num_leaves=40;, score=0.986 total time=  12.5s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012271 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2990
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 179
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [CV 3/5] END boosting_type=dart, learning_rate=0.01, min_child_weight=1, n_estimators=500, num_leaves=40;, score=0.988 total time=  14.4s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002312 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2980
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 174
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [CV 2/5] END boosting_type=gbdt, learning_rate=0.01, min_child_weight=5, n_estimators=500, num_leaves=10;, score=0.989 total time=   1.4s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002384 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2990
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 179
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [CV 1/5] END boosting_type=gbdt, learning_rate=0.01, min_child_weight=5, n_estimators=500, num_leaves=10;, score=0.988 total time=   4.3s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.011730 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2979
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 174
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [CV 4/5] END boosting_type=dart, learning_rate=0.01, min_child_weight=1, n_estimators=500, num_leaves=40;, score=0.985 total time=  17.2s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [CV 3/5] END boosting_type=gbdt, learning_rate=0.01, min_child_weight=5, n_estimators=500, num_leaves=10;, score=0.991 total time=   2.2s
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.064033 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2987
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 178
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009439 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2990
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 179
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [CV 4/5] END boosting_type=gbdt, learning_rate=0.01, min_child_weight=5, n_estimators=500, num_leaves=10;, score=0.988 total time=   2.1s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009790 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2980
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 174
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 5/5] END boosting_type=gbdt, learning_rate=0.01, min_child_weight=5, n_estimators=500, num_leaves=10;, score=0.984 total time=   5.1s
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017677 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2990
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 179
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 1/5] END boosting_type=dart, learning_rate=0.5, min_child_weight=5, n_estimators=500, num_leaves=10;, score=0.993 total time=   6.1s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009934 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2979
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 174
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 5/5] END boosting_type=dart, learning_rate=0.01, min_child_weight=1, n_estimators=500, num_leaves=40;, score=0.983 total time=  16.5s[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 2/5] END boosting_type=dart, learning_rate=0.5, min_child_weight=5, n_estimators=500, num_leaves=10;, score=0.996 total time=   8.1s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.026166 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2987
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 178
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007127 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2990
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 179
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 1/5] END boosting_type=dart, learning_rate=0.05, min_child_weight=10, n_estimators=50, num_leaves=40;, score=0.978 total time=   1.0s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.024822 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2980
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 174
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2990
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 179
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [CV 2/5] END boosting_type=dart, learning_rate=0.05, min_child_weight=5, n_estimators=50, num_leaves=30;, score=0.985 total time=   1.0s
# [CV 1/5] END boosting_type=dart, learning_rate=0.1, min_child_weight=10, n_estimators=10, num_leaves=20;, score=0.973 total time=   0.3s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009188 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2987
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 178
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.014265 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2980
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 174
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001388 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2990
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 179
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [CV 4/5] END boosting_type=dart, learning_rate=0.05, min_child_weight=5, n_estimators=50, num_leaves=30;, score=0.982 total time=   1.2s
# [CV 3/5] END boosting_type=dart, learning_rate=0.1, min_child_weight=10, n_estimators=10, num_leaves=20;, score=0.976 total time=   0.4s
# [CV 2/5] END boosting_type=dart, learning_rate=0.1, min_child_weight=10, n_estimators=10, num_leaves=20;, score=0.977 total time=   0.6s
# [CV 5/5] END boosting_type=dart, learning_rate=0.05, min_child_weight=5, n_estimators=50, num_leaves=30;, score=0.978 total time=   1.1s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.016212 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2987
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 178
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008523 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2979
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 174
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [CV 4/5] END boosting_type=dart, learning_rate=0.1, min_child_weight=10, n_estimators=10, num_leaves=20;, score=0.975 total time=   0.4s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002969 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2980
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 174
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013468 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.[LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
#
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Info] Total Bins 2990
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 179
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [CV 5/5] END boosting_type=dart, learning_rate=0.1, min_child_weight=10, n_estimators=10, num_leaves=20;, score=0.965 total time=   0.6s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004058 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2990
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 179
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012006 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2979
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 174
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [CV 1/5] END boosting_type=dart, learning_rate=0.1, min_child_weight=1, n_estimators=500, num_leaves=20;, score=0.996 total time=   8.4s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005499 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2987
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 178
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [CV 3/5] END boosting_type=dart, learning_rate=0.1, min_child_weight=1, n_estimators=500, num_leaves=20;, score=0.998 total time=   8.7s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.050779 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2990
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 179
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [CV 1/5] END boosting_type=gbdt, learning_rate=0.5, min_child_weight=1, n_estimators=10, num_leaves=10;, score=0.985 total time=   0.4s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010272 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2980
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 174
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [CV 2/5] END boosting_type=gbdt, learning_rate=0.5, min_child_weight=1, n_estimators=10, num_leaves=10;, score=0.988 total time=   0.4s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001339 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2990
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 179
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [CV 3/5] END boosting_type=gbdt, learning_rate=0.5, min_child_weight=1, n_estimators=10, num_leaves=10;, score=0.991 total time=   0.3s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004684 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2979
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 174
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [CV 4/5] END boosting_type=gbdt, learning_rate=0.5, min_child_weight=1, n_estimators=10, num_leaves=10;, score=0.988 total time=   0.3s
# [LightGBM] [Info] Number of positive: 2932, number of negative: 2876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.027223 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2987
# [LightGBM] [Info] Number of data points in the train set: 5808, number of used features: 178
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [CV 5/5] END boosting_type=gbdt, learning_rate=0.5, min_child_weight=1, n_estimators=10, num_leaves=10;, score=0.978 total time=   0.3s
# [CV 2/5] END boosting_type=dart, learning_rate=0.1, min_child_weight=1, n_estimators=500, num_leaves=20;, score=0.996 total time=  11.0s
# [CV 4/5] END boosting_type=dart, learning_rate=0.1, min_child_weight=1, n_estimators=500, num_leaves=20;, score=0.996 total time=  11.8s
# [CV 5/5] END boosting_type=dart, learning_rate=0.1, min_child_weight=1, n_estimators=500, num_leaves=20;, score=0.995 total time=   4.6s
# [LightGBM] [Info] Number of positive: 3665, number of negative: 3595
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002888 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3032
# [LightGBM] [Info] Number of data points in the train set: 7260, number of used features: 200
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504821 -> initscore=0.019284
# [LightGBM] [Info] Start training from score 0.019284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# RandomizedSearchCV(cv=5,
#                    estimator=LGBMClassifier(nthread=8, objective='binary',
#                                             seed=1, verbosity=1),
#                    n_iter=30, n_jobs=4,
#                    param_distributions={'boosting_type': ['gbdt', 'dart'],
#                                         'learning_rate': [0.5, 0.1, 0.05, 0.01,
#                                                           0.005],
#                                         'min_child_weight': [1, 5, 10],
#                                         'n_estimators': [10, 50, 100, 500],
#                                         'num_leaves': [10, 20, 30, 40]},
#                    random_state=42, scoring='roc_auc', verbose=3)

# %%
final_model = random_search.best_estimator_
{
    key: final_model.get_params()[key]
    for key in final_model.get_params()
    if key in lgb_params
}
# Out:
# {'boosting_type': 'gbdt',
#  'learning_rate': 0.5,
#  'min_child_weight': 1,
#  'n_estimators': 100,
#  'num_leaves': 20}

# %%
y_pred = final_model.predict_proba(X_train)[:, 1]
print(f"Score on training set: {roc_auc_score(y_train, y_pred)}")
# Out:
# Score on training set: 1.0

# %%
y_pred = final_model.predict_proba(X_val)[:, 1]
print(f"Score on validation set: {roc_auc_score(y_val, y_pred)}")
# Out:
# Score on validation set: 0.997280938883667

# %%
y_pred = final_model.predict_proba(X_test)[:, 1]
print(f"Score on test set: {roc_auc_score(y_test, y_pred)}")
# Out:
# Score on test set: 0.9961274475510886

# %% [markdown]
# ## Result of Experiment

# %%
res = pd.DataFrame({
    "Training Approach": [
        "Untuned SGDClassifier",
        "Tuned SGDClassifier",
        "Tuned LGBM",
    ],
    "ROC-AUC on Training Set": [
        0.5,
        0.8091939881637943,
        1.0,
    ],
    "ROC-AUC on Validation Set": [
        0.5,
        0.8289620691581475,
        0.997280938883667,
    ],
    "ROC-AUC on Test Set": [
        0.5,
        0.7998814604077762,
        0.9961274475510886,
    ],
})
res
# Out:
#        Training Approach  ROC-AUC on Training Set  ROC-AUC on Validation Set  \
# 0  Untuned SGDClassifier                 0.500000                   0.500000
# 1    Tuned SGDClassifier                 0.809194                   0.828962
# 2             Tuned LGBM                 1.000000                   0.997281
#
#    ROC-AUC on Test Set
# 0             0.500000
# 1             0.799881
# 2             0.996127

# %% [markdown]
# > Summary: Tuned LGBM gives the ROC-AUC boost both in training, validation, and test set. It also gives the best ROC-AUC compared to SGDClassifier both tuned and untuned version. In this experiment, we can also see that SGDClassifier performing well when it's tuned rather than plain SGDClassifier
#
# > So, we'll take the Tuned LGBM as a chosen model that will be deployed to production grade code

# %% [markdown]
# Choosen model is:
#
# ```python
# model = LGBMClassifier(
#   boosting_type='gbdt',
#   learning_rate=0.5,
#   min_child_weight=1,
#   n_estimators=100,
#   num_leaves=20,
#   random_state=42
# )
# ```
